# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-2023/coding-two-advanced-frameworks/blob/patch-1/first_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d6f26647-7453-4d16-9518-33eb670af0b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6f26647-7453-4d16-9518-33eb670af0b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv(io.BytesIO(uploaded['1.spotify do this.csv']))

# %%
# 检查DataFrame的前几行来确认数据加载正确
print(data.head())
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 设置图形的整体风格为白色网格
sns.set(style="whitegrid")

# 准备数据，将感兴趣的特性选择出来
features = ['danceability', 'energy', 'loudness', 'tempo']
data_features = data[features + ['playlist_genre']]

# 将数据“融合”，以便于制作小提琴图
data_melted = data_features.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# 创建小提琴图
plt.figure(figsize=(15, 10))
violin_plot = sns.violinplot(x="Feature", y="Value", hue="playlist_genre", data=data_melted, palette="muted", split=True)

# 设置标题和调整图例位置
plt.title('Distribution of Musical Features Across Genres')
plt.legend(title='Genre', loc='upper right', bbox_to_anchor=(1.25, 1))

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Your data loading code here
# For example:
# data = pd.read_csv('path_to_your_data.csv')

# Set the overall aesthetic style to 'whitegrid'
sns.set(style="whitegrid")

# Prepare the data, selecting the features of interest
features = ['danceability', 'energy', 'loudness', 'tempo']
data_features = data[features + ['playlist_genre']]

# Melt the data to transform it for the violin plot
data_melted = data_features.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# Create the violin plot
plt.figure(figsize=(15, 10))
violin_plot = sns.violinplot(x="Feature", y="Value", hue="playlist_genre", data=data_melted, palette='muted')

# Set the title and adjust the legend position
plt.title('Distribution of Musical Features Across Genres')
plt.legend(title='Genre', loc='upper right', bbox_to_anchor=(1.25, 1))

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 例如，定义一个莫兰迪色系的颜色列表
morandi_colors = ['#76877D', '#90A8A4', '#A6B1B7', '#BBBABF', '#C4C4C4', '#B8B0A3']

# 在这里加载您的数据
# data = pd.read_csv('您数据的路径.csv')

# 设置图形的整体风格为白色网格
sns.set(style="whitegrid")

# 准备数据，将感兴趣的特性选择出来
features = ['danceability', 'energy', 'loudness', 'tempo']
data_features = data[features + ['playlist_genre']]

# 将数据“融合”，以便于制作小提琴图
data_melted = data_features.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# 创建小提琴图
plt.figure(figsize=(15, 10))
# 使用自定义的莫兰迪色系调色板
violin_plot = sns.violinplot(x="Feature", y="Value", hue="playlist_genre", data=data_melted, palette=morandi_colors)

# 设置标题和调整图例位置
plt.title('音乐特征在不同流派中的分布')
plt.legend(title='流派', loc='upper right', bbox_to_anchor=(1.25, 1))

# 显示图表
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38899 (\N{CJK UNIFIED IDEOGRAPH-97F3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22312 (\N{CJK UNIFIED IDEOGRAPH-5728}) missing from current font.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

# 设置matplotlib支持中文显示
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 指定默认字体为黑体
matplotlib.rcParams['axes.unicode_minus'] = False  # 解决保存图像时负号'-'显示为方块的问题

# 定义一个莫兰迪色系的颜色列表
morandi_colors = ['#76877D', '#90A8A4', '#A6B1B7', '#BBBABF', '#C4C4C4', '#B8B0A3']

# 在这里加载您的数据
# data = pd.read_csv('您数据的路径.csv')

# 设置图形的整体风格为白色网格
sns.set(style="whitegrid")

# 准备数据，将感兴趣的特性选择出来
features = ['danceability', 'energy', 'loudness', 'tempo']
data_features = data[features + ['playlist_genre']]

# 将数据“融合”，以便于制作小提琴图
data_melted = data_features.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# 创建小提琴图
plt.figure(figsize=(15, 10))
violin_plot = sns.violinplot(x="Feature", y="Value", hue="playlist_genre", data=data_melted, palette=morandi_colors)

# 设置标题和调整图例位置
plt.title('音乐特征在不同流派中的分布')
plt.legend(title='流派', loc='upper right', bbox_to_anchor=(1.25, 1))

# 显示图表
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38899 (\N{CJK UNIFIED IDEOGRAPH-97F3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22312 (\N{CJK UNIFIED IDEOGRAPH-5728}) missing from current font.
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import seaborn as sns
import pandas as pd

# Attempt to set the font to a commonly available Chinese font
font = 'SimHei'
plt.rcParams['font.sans-serif'] = [font]
plt.rcParams['axes.unicode_minus'] = False

# Define your color palette
morandi_colors = ['#76877D', '#90A8A4', '#A6B1B7', '#BBBABF', '#C4C4C4', '#B8B0A3']

# Load your data
# data = pd.read_csv('your_data.csv')

# Set the overall style
sns.set(style="whitegrid")

# Prepare your data for the violin plot
# ... your data manipulation code ...

# Create the violin plot
plt.figure(figsize=(15, 10))
violin_plot = sns.violinplot(
    # ... your plotting code ...
    palette=morandi_colors
)

# Set the title and adjust the legend
plt.title('音乐特征在不同流派中的分布', fontsize=14)
plt.legend(title='流派', loc='upper right', bbox_to_anchor=(1.25, 1))

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38899 (\N{CJK UNIFIED IDEOGRAPH-97F3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# !apt-get install -y fonts-noto-cjk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   fonts-noto-cjk-extra
# The following NEW packages will be installed:
#   fonts-noto-cjk
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 61.2 MB of archives.
# After this operation, 93.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-cjk all 1:20220127+repack1-1 [61.2 MB]
# Fetched 61.2 MB in 2s (26.4 MB/s)
# Selecting previously unselected package fonts-noto-cjk.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../fonts-noto-cjk_1%3a20220127+repack1-1_all.deb ...
# Unpacking fonts-noto-cjk (1:20220127+repack1-1) ...
# Setting up fonts-noto-cjk (1:20220127+repack1-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Simulate some data for demonstration purposes
np.random.seed(10)
data = pd.DataFrame({
    'danceability': np.random.rand(100),
    'energy': np.random.rand(100),
    'loudness': np.random.randint(-60, 0, 100),
    'tempo': np.random.randint(50, 200, 100),
    'playlist_genre': np.random.choice(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], 100)
})

# Prepare the data, selecting the features of interest
features = ['danceability', 'energy', 'loudness', 'tempo']
data_features = data[features + ['playlist_genre']]

# Melt the data to prepare for the violin plot
data_melted = data_features.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# Set the overall aesthetic style to 'whitegrid'
sns.set(style="whitegrid")

# Create the violin plot
plt.figure(figsize=(15, 10))
violin_plot = sns.violinplot(
    x="Feature",
    y="Value",
    hue="playlist_genre",
    data=data_melted,
    palette='muted'
)

# Set the title and adjust the legend position
plt.title('Distribution of Musical Features Across Genres', fontsize=16)
plt.legend(title='Genre', loc='upper right', bbox_to_anchor=(1.25, 1))

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Simulate some data for demonstration purposes
np.random.seed(10)
data = pd.DataFrame({
    'danceability': np.random.rand(100),
    'energy': np.random.rand(100),
    'loudness': np.random.randint(-60, 0, 100),
    'tempo': np.random.randint(50, 200, 100),
    'playlist_genre': np.random.choice(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], 100)
})

# Prepare the data, selecting the features of interest
features = ['danceability', 'energy', 'loudness', 'tempo']
data_features = data[features + ['playlist_genre']]

# Melt the data to prepare for the violin plot
data_melted = data_features.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# Set the overall aesthetic style to 'whitegrid'
sns.set(style="whitegrid")

# Define a custom color palette
custom_palette = sns.color_palette("husl", 6)  # "husl" is a color palette with distinct colors

# Create the violin plot using the custom color palette
plt.figure(figsize=(15, 10))
violin_plot = sns.violinplot(
    x="Feature",
    y="Value",
    hue="playlist_genre",
    data=data_melted,
    palette=custom_palette
)

# Set the title and adjust the legend position
plt.title('Distribution of Musical Features Across Genres', fontsize=16)
plt.legend(title='Genre', loc='upper right', bbox_to_anchor=(1.25, 1))

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate some example data
np.random.seed(10)
data_example = pd.DataFrame({
    'danceability': np.random.rand(200),
    'energy': np.random.rand(200),
    'loudness': np.random.normal(-20, 5, 200),
    'tempo': np.random.normal(120, 30, 200),
    'playlist_genre': np.random.choice(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], 200)
})

# Melt the example DataFrame
data_melted = data_example.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# Set the style
sns.set(style="whitegrid")

# Create a violin plot with an explicitly defined color palette
plt.figure(figsize=(10, 8))
sns.violinplot(x='Feature', y='Value', hue='playlist_genre', data=data_melted, palette='bright')

# Set the title
plt.title('Violin Plot of Musical Features by Genre')

# Place the legend outside the plot
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc=2)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate some example data
np.random.seed(10)
data_example = pd.DataFrame({
    'danceability': np.random.rand(200),
    'energy': np.random.rand(200),
    'loudness': np.random.normal(-20, 5, 200),
    'tempo': np.random.normal(120, 30, 200),
    'playlist_genre': np.random.choice(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], 200)
})

# Melt the example DataFrame
data_melted = data_example.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# Set the style
sns.set(style="whitegrid")

# Create a violin plot with an explicitly defined color palette
plt.figure(figsize=(10, 8))
sns.violinplot(x='Feature', y='Value', hue='playlist_genre', data=data_melted, palette='bright')

# Set the title
plt.title('Violin Plot of Musical Features by Genre')

# Place the legend outside the plot
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc=2)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate some example data
np.random.seed(10)
data_example = pd.DataFrame({
    'danceability': np.random.rand(200),
    'energy': np.random.rand(200),
    'loudness': np.random.normal(-20, 5, 200),
    'tempo': np.random.normal(120, 30, 200),
    'playlist_genre': np.random.choice(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], 200)
})

# Melt the example DataFrame
data_melted = data_example.melt(id_vars='playlist_genre', var_name='Feature', value_name='Value')

# Set the style
sns.set(style="whitegrid")

# Define a direct list of hex colors for the palette
direct_palette = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4']

# Create a violin plot with the direct palette
plt.figure(figsize=(10, 8))
sns.violinplot(x='Feature', y='Value', hue='playlist_genre', data=data_melted, palette=direct_palette)

# Set the title
plt.title('Violin Plot of Musical Features by Genre')

# Place the legend outside the plot
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc=2)

# Display the plot
plt.show()
