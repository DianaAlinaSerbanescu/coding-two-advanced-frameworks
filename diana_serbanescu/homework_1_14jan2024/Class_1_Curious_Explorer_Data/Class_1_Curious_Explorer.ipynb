# %% [markdown]
# <a href="https://colab.research.google.com/github/DianaAlinaSerbanescu/coding-two-advanced-frameworks/blob/main/Class_1_Curious_Explorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning from data.
#
# ### Basic Setup:
#
# First, let's import a few common modules, ensure MatplotLib plots figures inline and prepare a function to save the figures. We also check that Python 3.5 or later is installed (although Python 2.x may work, it is deprecated so we strongly recommend you use Python 3 instead), as well as Scikit-Learn ≥0.20.

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CLASS_ID = "Curious explorer"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CLASS_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

print("Roger. Basic Setup Phase finished!")
# Out:
# Roger. Basic Setup Phase finished!

# %% [markdown]
# ## Get the Data from online source
#
# First, download the Data locally as a CVS file and then uplpoad the file in /sample_data

# %%
import pandas as pd
import os


CHOSEN_PATH = os.getcwd()+"/sample_data"

def load_chosen_data(chosen_path=CHOSEN_PATH):
    print(CHOSEN_PATH + ".")
    csv_path = os.path.join(chosen_path, "edsc_collection_results_export.csv")
    return pd.read_csv(csv_path)

# %% [markdown]
# ### Take a quick look at the data structure

# %%
chosen_data = load_chosen_data()
chosen_data.head()
# Out:
# /content/sample_data.
#   Data Provider            Short Name  Version  \
# 0     LARC_ASDC    FIRE_AX_ECMWF_DIAG        1
# 1     LARC_ASDC  FIRE_AX_SOF_BUOY_SPR        1
# 2     LARC_ASDC   FIRE_AX_SOF_SUR_HYD        1
# 3     LARC_ASDC  FIRE_AX_ECMWF_SURFCE        1
# 4     LARC_ASDC  FIRE_AX_ERS1_SCTRMTR        1
#
#                                          Entry Title  Processing Level  \
# 0  First ISCCP Regional Experiment (FIRE) Atlanti...                 4
# 1  First ISCCP Regional Experiment (FIRE) Atlanti...                 2
# 2  First ISCCP Regional Experiment (FIRE) Atlanti...                 2
# 3  First ISCCP Regional Experiment (FIRE) Atlanti...                 4
# 4  First ISCCP Regional Experiment (FIRE) Atlanti...                 2
#
#           Platform                Start Time                  End Time
# 0  Models/Analyses  1992-06-01T00:00:00.000Z  1992-06-28T23:59:59.999Z
# 1            BUOYS  1992-06-01T00:00:00.000Z  1992-06-30T23:59:59.999Z
# 2            BUOYS  1992-06-02T00:00:00.000Z  1992-06-19T23:59:59.999Z
# 3  Models/Analyses  1992-06-01T00:00:00.000Z  1992-06-28T23:59:59.999Z
# 4            ERS-1  1992-06-01T00:00:00.000Z  1992-06-29T23:59:59.999Z

# %%
chosen_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Data Provider     8 non-null      object
#  1   Short Name        8 non-null      object
#  2   Version           8 non-null      int64
#  3   Entry Title       8 non-null      object
#  4   Processing Level  8 non-null      int64
#  5   Platform          8 non-null      object
#  6   Start Time        8 non-null      object
#  7   End Time          8 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 640.0+ bytes

# %%
chosen_data.describe()
# Out:
#        Version  Processing Level
# count      8.0           8.00000
# mean       1.0           2.50000
# std        0.0           0.92582
# min        1.0           2.00000
# 25%        1.0           2.00000
# 50%        1.0           2.00000
# 75%        1.0           2.50000
# max        1.0           4.00000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
chosen_data.hist(bins=50, figsize=(20,15))
save_fig("attribute_histogram_plots")
plt.show()
# Out:
# Saving figure attribute_histogram_plots
