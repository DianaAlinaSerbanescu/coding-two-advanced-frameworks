# %%
pip install tensorflow ipywidgets matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.9 MB/s eta 0:00:00
# ...

# %%
import IPython.display as display
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input, decode_predictions
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

mobilenet = MobileNet(weights='imagenet')

def classify_img(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    preds = mobilenet.predict(x)

    print('Predictions:', decode_predictions(preds, top=3)[0])

img_path = '/content/sample_data/kitten.jpeg'
display.display(Image.open(img_path))

classify_img(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=182x171>
# 1/1 [==============================] - 0s 364ms/step
# Predictions: [('n02123045', 'tabby', 0.7757384), ('n02123394', 'Persian_cat', 0.15391506), ('n02124075', 'Egyptian_cat', 0.030339194)]
