# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-2023/coding-two-advanced-frameworks/blob/patch-3/homework_3_2feb2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

class Perceptron:
    def __init__(self):
        # Initialize weights to random values
        self.weights = np.random.uniform(-1, 1, 3)

    def guess(self, inputs):
        # Weighted sum of inputs and weights
        total = np.dot(inputs, self.weights)
        # Activation function
        return 1 if total >= 0 else -1

    def train(self, inputs, target):
        guess = self.guess(inputs)
        error = target - guess
        # Tune all the weights
        self.weights += error * inputs * self.lr

    def draw_line(self):
        # Calculate points on the line
        x1, x2 = 0, 1
        y1 = (-self.weights[2] - self.weights[0] * x1) / self.weights[1]
        y2 = (-self.weights[2] - self.weights[0] * x2) / self.weights[1]
        # Plot the line
        plt.plot([x1, x2], [y1, y2], 'g-')

class Point:
    def __init__(self, width, height):
        self.x = np.random.uniform(0, width)
        self.y = np.random.uniform(0, height)
        self.label = 1 if self.x > self.y else -1

    def display(self):
        color = 'b' if self.label == 1 else 'r'
        plt.plot(self.x, self.y, marker='o', color=color)

# Set up the canvas
width, height = 800, 800
points = [Point(width, height) for _ in range(100)]
perceptron = Perceptron()

# Set up the plot
plt.figure(figsize=(8, 8))
plt.xlim(0, width)
plt.ylim(0, height)

# Draw points and the initial line
for point in points:
    point.display()
perceptron.draw_line()

plt.show()
