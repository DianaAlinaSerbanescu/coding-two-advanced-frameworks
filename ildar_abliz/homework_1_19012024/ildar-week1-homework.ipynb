# %%
import os
import pandas as pd
pd.plotting.register_matplotlib_converters()

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Path of the file to read
countrylive_filepath = "./sample_data/best-countries-to-live-in-2024.csv"

# Read the file into a variable iris_data
countrylive_data = pd.read_csv(countrylive_filepath, index_col="country")

# Print the first 5 rows of the data
countrylive_data.head(15)
# Out:
#                population_2024  population_growthRate  land_area  \
# country
# India               1441719852                0.00916    3287590
# China               1425178782               -0.00035    9706961
# United States        341814420                0.00535    9372610
# Indonesia            279798049                0.00816    1904569
# Pakistan             245209815                0.01964     881912
# Nigeria              229152217                0.02389     923768
# Brazil               217637297                0.00561    8515767
# Bangladesh           174701211                0.01010     147570
# Russia               143957079               -0.00337   17098242
# Ethiopia             129719719                0.02523    1104300
# Mexico               129388467                0.00726    1964375
# Japan                122631432               -0.00538     377930
# Philippines          119106224                0.01508     342353
# Egypt                114484252                0.01568    1002450
# Vietnam               99497680                0.00646     331212
#
#                       region  unMember  population_density  \
# country
# India                   Asia      True            484.9067
# China                   Asia      True            151.2174
# United States  North America      True             37.3673
# Indonesia               Asia      True            149.0254
# Pakistan                Asia      True            318.0908
# Nigeria               Africa      True            251.6027
# Brazil         South America      True             26.0390
# Bangladesh              Asia      True           1342.1004
# Russia                Europe      True              8.7903
# Ethiopia              Africa      True            114.9415
# Mexico         North America      True             66.5596
# Japan                   Asia      True            336.4374
# Philippines             Asia      True            399.4574
# Egypt                 Africa      True            115.0075
# Vietnam                 Asia      True            317.4489
#
#                population_densityMi  \
# country
# India                     1255.9084
# China                      391.6530
# United States               96.7813
# Indonesia                  385.9758
# Pakistan                   823.8551
# Nigeria                    651.6511
# Brazil                      67.4409
# Bangladesh                3476.0401
# Russia                      22.7668
# Ethiopia                   297.6986
# Mexico                     172.3893
# Japan                      871.3729
# Philippines               1034.5948
# Egypt                      297.8695
# Vietnam                    822.1926
#
#                                                    share_borders  Hdi2021  \
# country
# India                     AFG, BGD, BTN, MMR, CHN, NPL, PAK, LKA    0.633
# China          AFG, BTN, MMR, HKG, IND, KAZ, PRK, KGZ, LAO, M...    0.768
# United States                                           CAN, MEX    0.921
# Indonesia                                          TLS, MYS, PNG    0.705
# Pakistan                                      AFG, CHN, IND, IRN    0.544
# Nigeria                                       BEN, CMR, TCD, NER    0.535
# Brazil          ARG, BOL, COL, GUF, GUY, PRY, PER, SUR, URY, VEN    0.754
# Bangladesh                                              MMR, IND    0.661
# Russia         AZE, BLR, CHN, EST, FIN, GEO, KAZ, PRK, LVA, L...    0.829
# Ethiopia                            DJI, ERI, KEN, SOM, SSD, SDN    0.498
# Mexico                                             BLZ, GTM, USA    0.758
# Japan                                                        NaN    0.925
# Philippines                                                  NaN    0.699
# Egypt                                              ISR, LBY, SDN    0.731
# Vietnam                                            KHM, CHN, LAO    0.703
#
#                Hdi2020  WorldHappiness2022
# country
# India            0.642               3.777
# China            0.764               5.585
# United States    0.920               6.977
# Indonesia        0.709               5.240
# Pakistan         0.543               4.516
# Nigeria          0.535               4.552
# Brazil           0.758               6.293
# Bangladesh       0.655               5.155
# Russia           0.830               5.459
# Ethiopia         0.498               4.241
# Mexico           0.756               6.128
# Japan            0.923               6.039
# Philippines      0.710               5.904
# Egypt            0.734               4.288
# Vietnam          0.710               5.485

# %%
# Histogram
sns.histplot(countrylive_data.head(15)['population_2024'], bins=10, kde=True, color='pink')
# Out:
# <Axes: xlabel='population_2024', ylabel='Count'>

# %%
# KDE plot
sns.kdeplot(data=countrylive_data['land_area'], shade=True)
# Out:
# <ipython-input-4-a48595d2b8c0>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=countrylive_data['land_area'], shade=True)
# <Axes: xlabel='land_area', ylabel='Density'>

# %%
sns.jointplot(x=countrylive_data['population_2024'], y=countrylive_data['land_area'], kind="kde", cmap="Blues")

# %%
# Histograms for each species
sns.histplot(data=countrylive_data.head(10), x='population_2024', hue='country')

# Add title
plt.title("population of each country")
# Out:
# Text(0.5, 1.0, 'population of each country')

# %%
# KDE plots for each species
sns.kdeplot(data=countrylive_data.tail(15), x='population_density', hue='region', shade=True)

# Add title
plt.title("land area of each country")
# Out:
# <ipython-input-7-00d300205d28>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=countrylive_data.tail(15), x='population_density', hue='region', shade=True)
# <ipython-input-7-00d300205d28>:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=countrylive_data.tail(15), x='population_density', hue='region', shade=True)
# Text(0.5, 1.0, 'land area of each country')
